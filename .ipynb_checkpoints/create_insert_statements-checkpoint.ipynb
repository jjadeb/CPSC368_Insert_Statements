# %%
import pandas as pd
from itertools import zip_longest

# %% [markdown]
# ### Load Datasets

# %%
air_quality_dat = pd.read_csv("data/CPSC368 DATA - Air Quality.csv")
ghg_emissions_dat_wide = pd.read_csv("data/CPSC368 DATA - GHG Emissions.csv")
global_climate_index_dat = pd.read_csv("data/CPSC368 DATA - Global Climate Index.csv")
paris_agreement_dat = pd.read_csv("data/CPSC368 DATA - Paris Agreement.csv")

# %% [markdown]
# ### Clean Datasets

# %%
# Clean data

# Make country names the same
global_climate_index_dat["Country"] = global_climate_index_dat["Country"].str.replace("-"," ")
paris_agreement_dat["Participant"] = paris_agreement_dat["Participant"].str.replace("-"," ")

# Remove null/non-country rows
ghg_emissions_dat_wide = ghg_emissions_dat_wide[:-4]
paris_agreement_dat = paris_agreement_dat.drop(paris_agreement_dat[paris_agreement_dat["Participant"] == "European Union"].index)

# Make year a column in greenhouse gas emissions data
ghg_emissions_dat = pd.melt(ghg_emissions_dat_wide, id_vars='Country', value_vars=['1970', '1971', '1972', '1973',
       '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
       '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
       '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019', '2020', '2021', '2022'], var_name = "Year", value_name = "Emissions")

# %%
# Change a country name to match the others
def alter_country_name(dataset, alter_dict, country_column_name):
    '''change country names in a dataset so it matches the values in other datasets
       example-- changing Brunei to Brunei Darussalam in one dataset so all datasets refer to Brunei in the same way

       INPUTS:
       dataset: dataset for which we are altering the country name
       change_dict: a dictionary where the key is country name we want to alter and the value is what we are changing to
       country_column_name: the column name of the column that contains countries

       RETURNS:
       altered dataset
       '''
    for original, changed in alter_dict.items():
        dataset.loc[dataset[country_column_name] == original, country_column_name] = changed
    return dataset


ghg_emissions_dat = alter_country_name(ghg_emissions_dat, {'Brunei':"Brunei Darussalam",
                                                           "Czechia":"Czech Republic",
                                                           'Côte d’Ivoire':"Côte d'Ivoire",
                                                           "Iran":"Iran (Islamic Republic of)",
                                                           "Laos":"Lao People's Democratic Republic",
                                                           "South Korea":'Republic of Korea',
                                                           'Vietnam':'Viet Nam',
                                                           "Russia":"Russian Federation",
                                                           "The Gambia":"Gambia",
                                                           "Myanmar/Burma":"Myanmar",
                                                           "Saint Lucia":"St.Lucia",
                                                           "Saint Pierre and Miquelon":"St.Pierre and Miquelon",
                                                           "Saint Vincent and the Grenadines":"St.Vincent and the Grenadines",
                                                           "Saint Kitts and Nevis":"St.Kitts and Nevis",
                                                           "Saint Helena, Ascension and Tristan":"St.Helena, Ascension and Tristan",
                                                           "Türkiye":"Turkey"
                                                           },
                                       "Country")
paris_agreement_dat = alter_country_name(paris_agreement_dat, {'Bolivia (Plurinational State of)':'Bolivia',
                                                               "Denmark 1":"Denmark",
                                                               "Micronesia (Federated States of)":"Micronesia",
                                                               "Netherlands (Kingdom of the) 2":"Netherlands",
                                                               "New Zealand 3":"New Zealand",
                                                               "Republic of Moldova":"Moldova",
                                                               "Yemen":'Republic of Yemen',
                                                               'St. Kitts and Nevis':'St.Kitts and Nevis',
                                                               'St. Lucia':'St.Lucia',
                                                               'St. Vincent and the Grenadines':'St.Vincent and the Grenadines',
                                                               'United Kingdom of Great Britain and Northern Ireland 4, 5, 6':'United Kingdom',
                                                               "United States of America 7":"United States of America",
                                                               "Venezuela (Bolivarian Republic of)":'Venezuela',
                                                               "United Republic of Tanzania":"Tanzania",
                                                               "Türkiye":"Turkey"},
                                         "Participant")
air_quality_dat = alter_country_name(air_quality_dat, {'Bolivia (Plurinational State of)':'Bolivia',
                                                       "Czechia":"Czech Republic",
                                                       "Venezuela (Bolivarian Republic of)":'Venezuela',
                                                       "United Republic of Tanzania":"Tanzania"},
                                     "WHO Country Name") 
global_climate_index_dat = alter_country_name(global_climate_index_dat, {'Republic of Congo':'Congo',
                                                                         "Islamic Republic of Iran":"Iran (Islamic Republic of)",
                                                                         'Islamic Republic of Afghanistan':"Afghanistan",
                                                                         "Kyrgyz Republic":"Kyrgyzstan",
                                                                         "Korea, Republic of":'Republic of Korea',
                                                                         "Russia":"Russian Federation",
                                                                         'Slovak Republic':'Slovakia',
                                                                         'United States':'United States of America',
                                                                         "The Gambia":"Gambia",
                                                                         "Vietnam":"Viet Nam",
                                                                         "Democratic Republic of Timor Leste":"Timor-Leste"},
                                              "Country")

# %% [markdown]
# ### Create Insert Statements

# %%
ghg_emissions_dat[ghg_emissions_dat["Country"] == 'Saint Lucia']
# Out:
# Empty DataFrame
# Columns: [Country, Year, Emissions]
# Index: []

# %%
# Clear conents of insert statement text file for clean state
open('data/insert_statements.txt','w').close()

# %%
# Find out which countries are not in the air-quality dataset
aq_countries = set(air_quality_dat["WHO Country Name"].unique())
ghg_emissions_countries = set(ghg_emissions_dat["Country"].unique())
gci_countries = set(global_climate_index_dat["Country"].unique())
pa_countries = set(paris_agreement_dat["Participant"].unique())
country_names_not_in_aq_countries = aq_countries.union(ghg_emissions_countries).union(gci_countries).union(pa_countries) - aq_countries

# %%
# Looking for inconsistencies in how the countries are represented textually
aq = sorted(aq_countries)
ghg = sorted(ghg_emissions_countries)
gci = sorted(gci_countries)
pa = sorted(pa_countries)

for c1, c2, c3, c4 in zip_longest(aq, ghg, gci, pa, fillvalue = ''):
    print(f'{c1:<35} {c2:<35} {c3:<35} {c4}')
# Out:
# Afghanistan                         Afghanistan                         Afghanistan                         Afghanistan
# Albania                             Albania                             Albania                             Albania
# Algeria                             Algeria                             Algeria                             Algeria
# Andorra                             Angola                              Angola                              Andorra
# Argentina                           Anguilla                            Antigua and Barbuda                 Angola
# Australia                           Antigua and Barbuda                 Argentina                           Antigua and Barbuda
# Austria                             Argentina                           Armenia                             Argentina
# Bahamas                             Armenia                             Australia                           Armenia
# Bahrain                             Aruba                               Austria                             Australia
# Bangladesh                          Australia                           Azerbaijan                          Austria
# Belgium                             Austria                             Bahrain                             Azerbaijan
# Bhutan                              Azerbaijan                          Bangladesh                          Bahamas
# Bolivia                             Bahamas                             Barbados                            Bahrain
# Bosnia and Herzegovina              Bahrain                             Belarus                             Bangladesh
# Brazil                              Bangladesh                          Belgium                             Barbados
# Bulgaria                            Barbados                            Belize                              Belarus
# Cameroon                            Belarus                             Benin                               Belgium
# Canada                              Belgium                             Bhutan                              Belize
# Chile                               Belize                              Bolivia                             Benin
# China                               Benin                               Bosnia and Herzegovina              Bhutan
# Colombia                            Bermuda                             Botswana                            Bolivia
# Costa Rica                          Bhutan                              Brazil                              Bosnia and Herzegovina
# Croatia                             Bolivia                             Brunei Darussalam                   Botswana
# Cuba                                Bosnia and Herzegovina              Bulgaria                            Brazil
# Cyprus                              Botswana                            Burkina Faso                        Brunei Darussalam
# Czech Republic                      Brazil                              Burundi                             Bulgaria
# Denmark                             Brunei Darussalam                   Cambodia                            Burkina Faso
# Ecuador                             Bulgaria                            Cameroon                            Burundi
# Egypt                               Burkina Faso                        Canada                              Cabo Verde
# El Salvador                         Burundi                             Cape Verde                          Cambodia
# Estonia                             Cabo Verde                          Central African Republic            Cameroon
# Ethiopia                            Cambodia                            Chad                                Canada
# Fiji                                Cameroon                            Chile                               Central African Republic
# Finland                             Canada                              China                               Chad
# France                              Cayman Islands                      Chinese Taipei                      Chile
# Georgia                             Central African Republic            Colombia                            China
# Germany                             Chad                                Comoros                             Colombia
# Ghana                               Chile                               Congo                               Comoros
# Greece                              China                               Costa Rica                          Congo
# Guatemala                           Colombia                            Croatia                             Cook Islands
# Honduras                            Comoros                             Cyprus                              Costa Rica
# Hungary                             Congo                               Czech Republic                      Croatia
# Iceland                             Cook Islands                        Côte d'Ivoire                       Cuba
# India                               Costa Rica                          Democratic Republic of Congo        Cyprus
# Indonesia                           Croatia                             Denmark                             Czech Republic
# Iran (Islamic Republic of)          Cuba                                Djibouti                            Côte d'Ivoire
# Iraq                                Curaçao                             Dominica                            Democratic People's Republic of Korea
# Ireland                             Cyprus                              Dominican Republic                  Democratic Republic of the Congo
# Israel                              Czech Republic                      Ecuador                             Denmark
# Italy                               Côte d'Ivoire                       Egypt                               Djibouti
# Jamaica                             Democratic Republic of the Congo    El Salvador                         Dominica
# Japan                               Denmark                             Eritrea                             Dominican Republic
# Jordan                              Djibouti                            Estonia                             Ecuador
# Kazakhstan                          Dominica                            Eswatini                            Egypt
# Kenya                               Dominican Republic                  Ethiopia                            El Salvador
# Kuwait                              Ecuador                             Fiji                                Equatorial Guinea
# Kyrgyzstan                          Egypt                               Finland                             Eritrea
# Lao People's Democratic Republic    El Salvador                         France                              Estonia
# Latvia                              Equatorial Guinea                   Gabon                               Eswatini
# Lebanon                             Eritrea                             Gambia                              Ethiopia
# Liechtenstein                       Estonia                             Georgia                             Fiji
# Lithuania                           Eswatini                            Germany                             Finland
# Luxembourg                          Ethiopia                            Ghana                               France
# Madagascar                          Falkland Islands                    Greece                              Gabon
# Malaysia                            Faroes                              Grenada                             Gambia
# Maldives                            Fiji                                Guatemala                           Georgia
# Malta                               Finland                             Guinea                              Germany
# Mauritius                           France and Monaco                   Guinea Bissau                       Ghana
# Mexico                              French Guiana                       Guyana                              Greece
# Monaco                              French Polynesia                    Haiti                               Grenada
# Mongolia                            Gabon                               Honduras                            Guatemala
# Montenegro                          Gambia                              Hungary                             Guinea
# Morocco                             Georgia                             Iceland                             Guinea Bissau
# Myanmar                             Germany                             India                               Guyana
# Nepal                               Ghana                               Indonesia                           Haiti
# Netherlands                         Gibraltar                           Iran (Islamic Republic of)          Holy See
# New Zealand                         Greece                              Iraq                                Honduras
# Nigeria                             Greenland                           Ireland                             Hungary
# North Macedonia                     Grenada                             Israel                              Iceland
# Norway                              Guadeloupe                          Italy                               India
# Pakistan                            Guatemala                           Jamaica                             Indonesia
# Panama                              Guinea                              Japan                               Iran (Islamic Republic of)
# Paraguay                            Guinea-Bissau                       Jordan                              Iraq
# Peru                                Guyana                              Kazakhstan                          Ireland
# Philippines                         Haiti                               Kenya                               Israel
# Poland                              Honduras                            Kiribati                            Italy
# Portugal                            Hong Kong                           Kosovo                              Jamaica
# Qatar                               Hungary                             Kuwait                              Japan
# Republic of Korea                   Iceland                             Kyrgyzstan                          Jordan
# Romania                             India                               Lao People's Democratic Republic    Kazakhstan
# Russian Federation                  Indonesia                           Latvia                              Kenya
# Saudi Arabia                        Iran (Islamic Republic of)          Lebanon                             Kiribati
# Senegal                             Iraq                                Lesotho                             Kuwait
# Serbia                              Ireland                             Liberia                             Kyrgyzstan
# Singapore                           Israel and Palestine, State of      Libya                               Lao People's Democratic Republic
# Slovakia                            Italy, San Marino and the Holy See  Lithuania                           Latvia
# Slovenia                            Jamaica                             Luxembourg                          Lebanon
# South Africa                        Japan                               Madagascar                          Lesotho
# Spain                               Jordan                              Malawi                              Liberia
# Sri Lanka                           Kazakhstan                          Malaysia                            Libya
# Sweden                              Kenya                               Maldives                            Liechtenstein
# Switzerland                         Kiribati                            Mali                                Lithuania
# Tajikistan                          Kuwait                              Malta                               Luxembourg
# Tanzania                            Kyrgyzstan                          Marshall Islands                    Madagascar
# Thailand                            Lao People's Democratic Republic    Mauritania                          Malawi
# Trinidad and Tobago                 Latvia                              Mauritius                           Malaysia
# Tunisia                             Lebanon                             Mexico                              Maldives
# Turkey                              Lesotho                             Micronesia                          Mali
# Turkmenistan                        Liberia                             Moldova                             Malta
# Uganda                              Libya                               Mongolia                            Marshall Islands
# Ukraine                             Lithuania                           Montenegro                          Mauritania
# United Arab Emirates                Luxembourg                          Morocco                             Mauritius
# United Kingdom                      Macao                               Mozambique                          Mexico
# United States of America            Madagascar                          Myanmar                             Micronesia
# Uruguay                             Malawi                              Namibia                             Moldova
# Uzbekistan                          Malaysia                            Nepal                               Monaco
# Venezuela                           Maldives                            Netherlands                         Mongolia
# Viet Nam                            Mali                                New Zealand                         Montenegro
#                                     Malta                               Nicaragua                           Morocco
#                                     Martinique                          Niger                               Mozambique
#                                     Mauritania                          Nigeria                             Myanmar
#                                     Mauritius                           North Macedonia                     Namibia
#                                     Mexico                              Norway                              Nauru
#                                     Moldova                             Oman                                Nepal
#                                     Mongolia                            Pakistan                            Netherlands
#                                     Morocco                             Panama                              New Zealand
#                                     Mozambique                          Papua New Guinea                    Nicaragua
#                                     Myanmar                             Paraguay                            Niger
#                                     Namibia                             Peru                                Nigeria
#                                     Nepal                               Philippines                         Niue
#                                     Netherlands                         Poland                              North Macedonia
#                                     New Caledonia                       Portugal                            Norway
#                                     New Zealand                         Puerto Rico                         Oman
#                                     Nicaragua                           Qatar                               Pakistan
#                                     Niger                               Republic of Korea                   Palau
#                                     Nigeria                             Republic of Yemen                   Panama
#                                     North Korea                         Romania                             Papua New Guinea
#                                     North Macedonia                     Russian Federation                  Paraguay
#                                     Norway                              Rwanda                              Peru
#                                     Oman                                Samoa                               Philippines
#                                     Pakistan                            Saudi Arabia                        Poland
#                                     Palau                               Senegal                             Portugal
#                                     Panama                              Serbia                              Qatar
#                                     Papua New Guinea                    Seychelles                          Republic of Korea
#                                     Paraguay                            Sierra Leone                        Republic of Yemen
#                                     Peru                                Singapore                           Romania
#                                     Philippines                         Slovakia                            Russian Federation
#                                     Poland                              Slovenia                            Rwanda
#                                     Portugal                            Solomon Islands                     Samoa
#                                     Puerto Rico                         South Africa                        San Marino
#                                     Qatar                               South Sudan                         Sao Tome and Principe
#                                     Republic of Korea                   Spain                               Saudi Arabia
#                                     Romania                             Sri Lanka                           Senegal
#                                     Russian Federation                  St.Kitts and Nevis                  Serbia
#                                     Rwanda                              St.Lucia                            Seychelles
#                                     Réunion                             St.Vincent and the Grenadines       Sierra Leone
#                                     Saint Helena, Ascension and Tristan da Cunha Sudan                               Singapore
#                                     Saudi Arabia                        Suriname                            Slovakia
#                                     Senegal                             Sweden                              Slovenia
#                                     Serbia and Montenegro               Switzerland                         Solomon Islands
#                                     Seychelles                          Tajikistan                          Somalia
#                                     Sierra Leone                        Tanzania                            South Africa
#                                     Singapore                           Thailand                            South Sudan
#                                     Slovakia                            The Bahamas                         Spain
#                                     Slovenia                            Timor Leste                         Sri Lanka
#                                     Solomon Islands                     Togo                                St.Kitts and Nevis
#                                     Somalia                             Tonga                               St.Lucia
#                                     Spain and Andorra                   Trinidad and Tobago                 St.Vincent and the Grenadines
#                                     Sri Lanka                           Tunisia                             State of Palestine
#                                     St.Kitts and Nevis                  Turkey                              Sudan
#                                     St.Lucia                            Tuvalu                              Suriname
#                                     St.Pierre and Miquelon              Uganda                              Sweden
#                                     St.Vincent and the Grenadines       Ukraine                             Switzerland
#                                     Sudan and South Sudan               United Arab Emirates                Syrian Arab Republic
#                                     Suriname                            United Kingdom                      Tajikistan
#                                     Sweden                              United States of America            Tanzania
#                                     Switzerland and Liechtenstein       Uruguay                             Thailand
#                                     Syria                               Uzbekistan                          Timor Leste
#                                     São Tomé and Príncipe               Vanuatu                             Togo
#                                     Taiwan                              Venezuela                           Tonga
#                                     Tajikistan                          Viet Nam                            Trinidad and Tobago
#                                     Tanzania                            Zambia                              Tunisia
#                                     Thailand                            Zimbabwe                            Turkey
#                                     Timor-Leste                                                             Turkmenistan
#                                     Togo                                                                    Tuvalu
#                                     Tonga                                                                   Uganda
#                                     Trinidad and Tobago                                                     Ukraine
#                                     Tunisia                                                                 United Arab Emirates
#                                     Turkey                                                                  United Kingdom
#                                     Turkmenistan                                                            United States of America
#                                     Turks and Caicos Islands                                                Uruguay
#                                     Uganda                                                                  Uzbekistan
#                                     Ukraine                                                                 Vanuatu
#                                     United Arab Emirates                                                    Venezuela
#                                     United Kingdom                                                          Viet Nam
#                                     United States                                                           Zambia
#                                     Uruguay                                                                 Zimbabwe
#                                     Uzbekistan
#                                     Venezuela
#                                     Western Sahara

# %%
# Create Country Table Insert Statements

# open insert statements file
insert_statements=open('data/insert_statements.txt','w')

# create table with country names and attributes from the air-quality dataset
aq_countries_df = air_quality_dat[["WHO Country Name","WHO Region","ISO3"]].drop_duplicates()

# create insert statements for countries in the air-quality dataset
for index, row in aq_countries_df.iterrows():
    insert_statements.write(f'INSERT INTO Country(Country_Name, WHO_Region, ISO)\n VALUES ({row["WHO Country Name"]},{row["WHO Region"]},{row["ISO3"]}) \n')

# create insert statements for countries NOT in the air-quality dataset
for leftover_country in country_names_not_in_aq_countries:
    insert_statements.write(f'INSERT INTO Country(Country_Name, WHO_Region, ISO)\n VALUES ({leftover_country},NULL,NULL) \n')

insert_statements.write(f'\n \n \n \n')
insert_statements.close()

# %%
# Create City Table Insert Statements

# open insert statements file
insert_statements=open('data/insert_statements.txt','a')

# create table with country names and city names from the air-quality dataset
aq_cities_df = air_quality_dat[["WHO Country Name","City or Locality"]].drop_duplicates()

# create insert statements for countries in the air-quality dataset
for index, row in aq_cities_df.iterrows():
    insert_statements.write(f'INSERT INTO City(City_Name,Country_Name)\n VALUES ({row["City or Locality"]},{row["WHO Country Name"]}) \n')

insert_statements.write(f'\n \n \n \n \n')
insert_statements.close()

# %%
# Create Air_Quality_Measures Table Insert Statements

# open insert statements file
insert_statements=open('data/insert_statements.txt','a')

# create insert statements for countries in the air-quality dataset
for index, row in air_quality_dat.iterrows():
    insert_statements.write(f'INSERT INTO Air_Quality_Measures(ID, Year, City_Name, Country_Name, NO2, PM10, PM2.5, NO2_temporal_coverage, PM2.5_temporal_coverage, PM10_temporal_coverage)\n VALUES ({index}, {row["Measurement Year"]}, {row["City or Locality"]}, {row["WHO Country Name"]}, {row["NO2 (μg/m3)"]}, {row["PM10 (μg/m3)"]}, {row["PM2.5 (μg/m3)"]}, {row["NO2 temporal coverage (%)"]}, {row["PM25 temporal coverage (%)"]}, {row["PM10 temporal coverage (%)"]}) \n')

insert_statements.write(f'\n \n \n \n \n')
insert_statements.close()

# %%
# Create Greenhouse_Gasses Table Insert Statements

insert_statements=open('data/insert_statements.txt','a')

# create insert statements for countries in the air-quality dataset
for index, row in ghg_emissions_dat.iterrows():
    insert_statements.write(f'INSERT INTO Greenhouse_Gasses(Year, Country_Name, Per_Capita_GHG) \n VALUES ({row["Year"]},{row["Country"]},{row["Emissions"]}) \n')

insert_statements.write(f'\n \n \n \n \n')
insert_statements.close()

# %%
# Create Paris_Agreement_Member Table Insert Statements

# Obtain countries not in Paris agreement
country_names_not_in_pa_countries = aq_countries.union(ghg_emissions_countries).union(gci_countries).union(pa_countries) - pa_countries

# open insert statements file
insert_statements=open('data/insert_statements.txt','a')

# create table with country names and attributes from the paris agreement dataset
pa_countries_df = paris_agreement_dat[["Participant","Ratification, Acceptance(A), Approval(AA), Accession(a)"]].drop_duplicates()

# create insert statements for countries in the paris agreement dataset
for index, row in pa_countries_df.iterrows():
    insert_statements.write(f'INSERT INTO Paris_Agreement_Member(Country_Name, Date_Joined)\n VALUES ({row["Participant"]},{row["Ratification, Acceptance(A), Approval(AA), Accession(a)"]}) \n')

insert_statements.write(f'\n \n \n \n')
insert_statements.close()

# %%
# Create Climate_Risk_Index Table Insert Statements

# open insert statements file
insert_statements=open('data/insert_statements.txt','a')

# create insert statements for countries in the climate risk index dataset
for index, row in global_climate_index_dat.iterrows():
    insert_statements.write(f'INSERT INTO Climate_Risk_Index(ID, Country_Name, CRI_Rank, CRI_Score, Fatalities_2018_Rank, Fatalities_Per_100000_Rank, US_Million_Losses_Rank, GDP_Losses_Rank) \n VALUES ({row["ID"]},{row["Country"]},{row["CRI Rank"]},{row["CRI score"]},{row["Fatalities in 2018 (Rank)"]},{row["Fatalities per 100 000 inhabitants (Rank)"]},{row["Losses in million US$ (PPP) (Rank)"]},{row["Losses per unit GDP in % (Rank)"]}) \n')

insert_statements.write(f'\n \n \n \n \n')
insert_statements.close()
