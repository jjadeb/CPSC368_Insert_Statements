# %%
import pandas as pd

gci = pd.read_csv("data/CPSC368 DATA - Global Climate Index OLD.csv")

# %%
gci.head()
# Out:
#    CRI Rank              Country  CRI score  Fatalities in 2018 (Rank)
# 0       125              Albania     108.00                        102  \
# 1       109              Algeria      93.83                         47
# 2        80               Angola      76.00                         52
# 3       135  Antigua-and-Barbuda     125.00                        115
# 4        40            Argentina      48.33                         61
#
#    Fatalities per 100 000 inhabitants (Rank)
# 0                                         87  \
# 1                                         76
# 2                                         72
# 3                                        115
# 4                                        101
#
#    Losses in million US$ (PPP) (Rank)  Losses per unit GDP in % (Rank)
# 0                                 124                              124
# 1                                 110                              127
# ...

# %%
gci["ID"] = range(1, len(gci) + 1)
gci = pd.concat([gci["ID"], gci.drop(columns = ["ID"])], axis = 1)
gci.head()
# Out:
#    ID  CRI Rank              Country  CRI score  Fatalities in 2018 (Rank)
# 0   1       125              Albania     108.00                        102  \
# 1   2       109              Algeria      93.83                         47
# 2   3        80               Angola      76.00                         52
# 3   4       135  Antigua-and-Barbuda     125.00                        115
# 4   5        40            Argentina      48.33                         61
#
#    Fatalities per 100 000 inhabitants (Rank)
# 0                                         87  \
# 1                                         76
# 2                                         72
# 3                                        115
# 4                                        101
#
#    Losses in million US$ (PPP) (Rank)  Losses per unit GDP in % (Rank)
# 0                                 124                              124
# 1                                 110                              127
# ...

# %%
gci.to_csv("data/CPSC368 DATA - Global Climate Index.csv", index = False)
